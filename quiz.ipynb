# %%
# 02장 연습문제

# %%
a = (7 + 3)
a
# Out:
# 10

# %%
a = round(3.1415, 2)
a
# 이 코드는 round() 함수를 사용하여 주어진 실수를 소수점 두 번째 자리에서 반올림하고, 그 결과를 변수 rounded_value에 저장합니다.
# Out:
# 3.14

# %%
b = 'Hello, World!'
c = b.split(',')[0]
c
# 이 코드는 문자열의 split() 메소드를 사용하여 쉼표를 기준으로 문자열을 나눈 후 첫 번째 원소를 변수 first_word에 저장합니다.
# Out:
# 'Hello'

# %%
a = 'Python'
b = a.upper()
b
# Out:
# 'PYTHON'

# %%
List = [1, 2, 3, 4, 5]
List[0], List[-1] = List[-1], List[0]
List
# 이 코드는 리스트 인덱싱과 변수 할당을 사용하여 첫 번째 원소와 마지막 원소의 값을 서로 교환합니다.
# Out:
# [5, 2, 3, 4, 1]

# %%
my_list = [5, 2, 7, 1, 9]
my_list.sort()
my_list
# 이 코드는 리스트의 sort() 메소드를 사용하여 리스트를 오름차순으로 정렬합니다.
# Out:
# [1, 2, 5, 7, 9]

# %%
a = ('apple', 'banana', 'cherry')
b = a[0]
b
# 이 코드는 인덱싱을 사용하여 튜플의 첫 번째 원소를 변수 first_element에 저장합니다.
# Out:
# 'apple'

# %%
a = (1, 2, 3)
b = (4, 5, 6)
c = a + b
c
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
my_dict = {'apple': 3, 'banana': 5, 'cherry': 2}

a= my_dict['banana']
a
# Out:
# 5

# %%
a = {'apple': 3, 'banana': 5, 'cherry': 2}
a['orange'] = 4
a
# 이 코드는 딕셔너리에 키 'orange'와 값 4를 추가합니다. 딕셔너리에 새로운 키-값 쌍을 추가할 때는 딕셔너리에 새로운 키를 인덱스로 사용하고 값을 할당합니다.
# Out:
# {'apple': 3, 'banana': 5, 'cherry': 2, 'orange': 4}

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}

set3 = set1.intersection(set2)
set3
# 이 코드는 두 집합의 intersection() 메소드를 사용하여 교집합을 구하고, 그 결과를 변수 intersection에 저장합니다.
# Out:
# {2, 3}

# %%
bool1 = True
bool2 = False

c = bool1 and bool2
c
# 이 코드는 두 불 값을 AND 연산하여 결과를 변수 result에 저장합니다. 파이썬에서 불 값의 AND 연산은 'and' 키워드를 사용합니다.
# Out:
# False

# %%
# 02장 되새김 문제

# %%
# 국어 80 / 영어 75 / 수학 55
avg = ( 80 + 75 + 55 ) / 3
avg
# Out:
# 70.0

# %%
a = 13
if ( a % 2 == 0):
    print("짝수입니다")
else:
    print("홀수입니다")
print(a)
# Out:
# 홀수입니다
# 13

# %%
pin = "881120-1068234"
yyyymmdd = pin[:6]  # (=) pin.split('-')[0]
num = pin[7:14]     # (=) pin.split('-')[-1]

print(yyyymmdd)
print(num)
# Out:
# 881120
# 1068234

# %%
pin = "881120-1062234"
sex = pin[7]
print(sex)
# Out:
# 1

# %%
a = "a:b:c:d"
b = a.replace(":", "#")
b
# Out:
# 'a#b#c#d'

# %%
a = [1, 3, 5, 4, 2]
a.sort()
a.reverse()
print(a)
# Out:
# [5, 4, 3, 2, 1]

# %%
a = ['Life', 'is', 'too', 'short']
b = (" ").join(a)
b
# a 리스트의 각 단어들을 한 문장으로 조립할 때 단어들 사이마다 공백을 넣어야 한다.
# 1개의 공백 문자 (" ")를 사용해 join한다.
# Out:
# 'Life is too short'

# %%
a = (1, 2, 3)
a = a + (4,)
a
# Out:
# (1, 2, 3, 4)

# %%
a = {'A': 90, 'B': 80, 'C': 70}
result = a.pop('B')
print(a)
print(result)
# Out:
# {'A': 90, 'C': 70}
# 80

# %%
a = [1, 1, 1, 2, 2, 3, 3, 3, 4, 4, 5]
b = set(a)
c = list(b)
print(c)
# Out:
# [1, 2, 3, 4, 5]

# %%
a = b = [1, 2, 3]
a[1] = 4
print(b)
# Out:
# [1, 4, 3]
